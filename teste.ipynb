# %%
import pandas as pd

# %%
pesquisa=pd.read_csv('pesquisa.csv', sep=';')
pesquisa.head(16)
# Out:
#                 sub_area_conhecimento  \
# 0                 ENGENHARIA DE MINAS
# 1                           ZOOTECNIA
# 2   CIÊNCIA E TECNOLOGIA DE ALIMENTOS
# 3                           ZOOTECNIA
# 4                    ENGENHARIA CIVIL
# 5                    INTERDISCIPLINAR
# 6                             QUÍMICA
# 7               CIÊNCIA DA COMPUTAÇÃO
# 8                              ENSINO
# 9                           FILOSOFIA
# 10                      ADMINISTRAÇÃO
# 11                             FÍSICA
# 12              CIÊNCIA DA COMPUTAÇÃO
# 13               ENGENHARIA SANITÁRIA
# 14                           EDUCAÇÃO
# 15                           HISTÓRIA
#
#                                                resumo fim_execucao  \
# 0                                               Teste   2015-06-24
# 1   Esta pesquisa terá como objetivos avaliar e co...   2016-03-31
# 2   O mercado de produtos diet a cada ano mostra-s...   2016-03-07
# ...

# %%
pesquisa.groupby('coordenador')['coordenador'].count().head(12)
# Out:
# coordenador
# Abigail Noadia Barbalho da Silva          3
# Abraao Jhonny da Costa Brazao             2
# Abrahao Christophe Bezerra Lopes          6
# Adalva Lopes Machado                      6
# Adan John Gomes da Silva                  1
# Ailton Deuzimar de Sousa Junior           2
# Ailton Torres Camara                     23
# Airton Araujo de Souza Junior             2
# Alan Jones Lira de Melo                   4
# Alan Klinger Sousa Alves                  4
# Alana Drizie Gonzatti dos Santos          6
# Alanderson Rafael dos Santos Medeiros     4
# Name: coordenador, dtype: int64
