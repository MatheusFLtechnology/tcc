# %%
import pandas as pd

# %%
extensao=pd.read_csv('extensao.csv', sep=';')
extensao.head(16)
# Out:
#                                                resumo fim_execucao  \
# 0   Resumo\r\n \r\nDois elementos inspiram a propo...   2012-12-14
# 1   De acordo com o PPP do IFRN, e sendo a Extensã...   2012-12-31
# 2   O presente projeto pretende dar uma acessoria ...   2012-12-31
# 3   O projeto apresentado objetiva a capacitação d...   2012-12-31
# 4   RESUMO\r\n\r\n\r\n A dificuldade no aprendiza...   2012-12-30
# 5   Este projeto visa disseminar a prática do xadr...   2013-01-20
# 6   O gênero textual resumo/abstract é bastante pr...   2012-12-31
# 7   Na sociedade globalizada, centrada no mercado,...   2012-12-21
# 8   Aborda a questão da prática da atividade físic...   2012-12-31
# 9   Nesse projeto serão diagnosticadas, as deficiê...   2012-12-30
# 10  Neste projeto pretende-se envolver os alunos n...   2012-12-03
# 11  O projeto “Construindo cidadãos solidários” bu...   2012-12-06
# 12  O presente projeto visa à execução de um curso...   2012-12-31
# ...

# %%
extensao['tipo']= 'extensao'
extensao
# Out:
#                                                  resumo fim_execucao  \
# 0     Resumo\r\n \r\nDois elementos inspiram a propo...   2012-12-14
# 1     De acordo com o PPP do IFRN, e sendo a Extensã...   2012-12-31
# 2     O presente projeto pretende dar uma acessoria ...   2012-12-31
# 3     O projeto apresentado objetiva a capacitação d...   2012-12-31
# 4     RESUMO\r\n\r\n\r\n A dificuldade no aprendiza...   2012-12-30
# ...                                                 ...          ...
# 3217  <p style="text-align: justify;"><span style="f...   2019-12-31
# 3218  <p style="text-align: justify;">O projeto &ldq...   2019-12-23
# 3219  <p align="justify" class="western" style="marg...   2020-01-31
# 3220  <p>A educa&ccedil;&atilde;o ambiental &eacute;...   2019-12-31
# 3221  <p class="MsoNoSpacing" style="margin:0cm; mar...   2019-12-20
#
#             area_conhecimento  \
# 0                    EDUCAÇÃO
# 1            ENGENHARIA CIVIL
# 2     ARQUITETURA E URBANISMO
# ...

# %%
extensao.groupby('fim_execucao')['fim_execucao'].count()
# Out:
# fim_execucao
# 2012-02-28    1
# 2012-02-29    1
# 2012-04-23    1
# 2012-04-30    1
# 2012-08-31    1
#              ..
# 2020-05-30    1
# 2020-06-30    1
# 2020-08-18    1
# 2020-11-01    1
# 2020-12-14    1
# Name: fim_execucao, Length: 708, dtype: int64

# %%
#quantos projetos foram feitas por tipo 
extensao.groupby('tipo')['tipo'].count()
# Out:
# tipo
# extensao    3222
# Name: tipo, dtype: int64

# %%
#quantos projetos de extensao foram feitas por campus 
extensao.groupby('campus')['campus'].count()
# Out:
# campus
# AP      132
# CA      178
# CAL     166
# CANG    111
# CM      122
# CN      207
# CNAT    518
# IP      156
# JC      141
# LAJ      70
# MC      196
# MO      181
# NC      177
# PAAS     76
# PAR     120
# PF      109
# SC      165
# SGA      86
# SPP      84
# ZL       57
# ZN      170
# Name: campus, dtype: int64

# %%
#quantos projetos de extensao foram feitas por areas 
extensao.groupby('area_conhecimento')['area_conhecimento'].count()
# Out:
# area_conhecimento
# ADMINISTRAÇÃO              130
# AGRONOMIA                   46
# ANTROPOLOGIA                10
# ARQUITETURA E URBANISMO     18
# ARTES                      286
#                           ...
# SOCIOLOGIA                  19
# TURISMO                     29
# ZOOLOGIA                     2
# ZOOTECNIA                   37
# teste                        2
# Name: area_conhecimento, Length: 64, dtype: int64

# %%
extensao['inicio_execucao'] = pd.to_datetime(extensao['inicio_execucao'], errors='coerce')
extensao['fim_execucao'] = pd.to_datetime(extensao['fim_execucao'], errors='coerce')
#pesquisa['inicio_execucao'] = pesquisa['inicio_execucao'].astype('datetime64[ns]')
extensao.groupby(extensao.inicio_execucao.dt.year)['inicio_execucao'].count()
# Out:
# inicio_execucao
# 2011      1
# 2012    258
# 2013    222
# 2014    287
# 2015    478
# 2016    498
# 2017    489
# 2018    502
# 2019    486
# 2106      1
# Name: inicio_execucao, dtype: int64

# %%
# preparação dos dados 
extensao.groupby(extensao.inicio_execucao.dt.year)['inicio_execucao'].count().plot.box()
# Out:
# <Axes: >

# %%
#Quantos projetos de extensão  foram desenvolvidos no campus canguaretama por ano?
extensao[extensao.campus == 'CANG'].groupby('campus')['campus'].count()
# Out:
# campus
# CANG    111
# Name: campus, dtype: int64

# %%
#Quantos projetos foram desenvolvidos por pesquisador
extensao[extensao.campus == 'CANG'].groupby('coordenador')['coordenador'].count()
# Out:
# coordenador
# Alberis Eron Flavio de Oliveira             2
# Alberto Correia Gomes Filho                 2
# Aldayr Dantas de Araujo Junior              5
# Alexandre Nascimento Barros                 1
# Alfredo Henrique Oliveira Marques           2
# Ana Kamily de Souza Sampaio                 1
# Ana Monica de Britto Costa                  1
# Ana Neri da Paz Justino                     4
# Anisia Karla de Lima Galvao                 3
# Avelino Aldo de Lima Neto                   2
# Bruno Augusto Ferreira Vitorino             1
# Bruno Gomes de Araujo                       8
# Candice Firmino de Azevedo                  1
# Darlyne Fontes Virginio                     1
# David da Silveira Mousinho                  1
# Epitacio Bronzeado Neto                     2
# Fellipe Jose Silva Ferreira                 5
# Francisco do Nascimento Lima                7
# Giulia Carolina de Melo                     1
# Helber Wagner da Silva                      8
# ...

# %%
# 5 campus com mais projetos de extensão
extensao.groupby('campus')['campus'].sum().sort_values(ascending=False).head(5)
# Out:
# campus
# ZN     ZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZNZN...
# ZL     ZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZLZL...
# SPP    SPPSPPSPPSPPSPPSPPSPPSPPSPPSPPSPPSPPSPPSPPSPPS...
# SGA    SGASGASGASGASGASGASGASGASGASGASGASGASGASGASGAS...
# SC     SCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSCSC...
# Name: campus, dtype: object

# %%
# os 5 campus com menos projetos de extensão 
extensao.groupby('campus')['campus'].count().sort_values().head(5)
# Out:
# campus
# ZL      57
# LAJ     70
# PAAS    76
# SPP     84
# SGA     86
# Name: campus, dtype: int64

# %%
# os 5 areas com menos projetos de extensão 
extensao.groupby('area_conhecimento')['area_conhecimento'].count().sort_values().head(5)
# Out:
# area_conhecimento
# BOTÂNICA                                      1
# RECURSOS FLORESTAIS E ENGENHARIA FLORESTAL    1
# PROBABILIDADE E ESTATÍSTICA                   1
# PLANEJAMENTO URBANO E REGIONAL                1
# GENÉTICA                                      1
# Name: area_conhecimento, dtype: int64

# %%
# media de projetos por pesquisadores projetos de pesquisa 
#extensao.groupby('area_conhecimento')['area_conhecimento'].min().sort_values(ascending=False).head(5)
#extensao.coordenador.median()
extensao.groupby('coordenador')['coordenador'].count().mean()
# Out:
# 2.685

# %%
# media de projetos por pesquisadores projetos de pesquisa 
#extensao.groupby('area_conhecimento')['area_conhecimento'].min().sort_values(ascending=False).head(5)
#extensao.coordenador.median()
extensao.groupby('coordenador')['coordenador'].count().std()
# Out:
# 2.349192894601613

# %% [markdown]
# ## gerando graficos

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
# 5 áreas com a maior quantidade de projetos de extensão
extensao_area = extensao.groupby('area_conhecimento')['area_conhecimento'].count().sort_values(ascending=False).head(5)
x = extensao_area.index
y = extensao_area.values
plt.figure(figsize=(10,5))
plt.bar(x,y)
plt.show()

# %%
# 5 Campi com menos projetos de extensão
extensao_campus = extensao.groupby('campus')['campus'].count().sort_values().head(5)
x = extensao_campus.index
y = extensao_campus.values
plt.figure(figsize=(10,5))
plt.bar(x,y)
plt.show()

# %%
# 5 áreas com a menor quantidade de projetos de extensão
extensao_conhecimento = extensao.groupby('area_conhecimento')['area_conhecimento'].count().sort_values().head(5)
x = extensao_conhecimento.index
y = extensao_conhecimento.values
#plt.figure(figsize=(10,5))
plt.xticks(rotation=-40)
plt.bar(x,y)
plt.show()

# %%
from datetime import datetime

#Cria as colunas e insere zero em todas as linhas delas
extensao['duracao_dias'] = 0
extensao['duracao_meses'] = 0

#for para percorrer todas as linhas do dataframe
for linha in range(len(extensao.index)):
  # Salva a data de início do projeto em variável
  inicio = extensao.loc[linha, 'inicio_execucao']
  # Salva a data de fim do projeto em variável
  fim = extensao.loc[linha, 'fim_execucao']

  #Converte para datetime as datas início e fim
  d1 = datetime.strptime(inicio, "%Y-%m-%d")
  d2 = datetime.strptime(fim, "%Y-%m-%d")

  #Calcula o tempo em dias entre a data de início e fim
  extensao.loc[linha, 'duracao_dias'] = float((abs((d2 - d1).days)))

  #Calcula o tempo em meses entre a data de início e fim
  extensao.loc[linha, 'duracao_meses'] = float((abs((d2 - d1).days/30)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 15
#      12 fim = extensao.loc[linha, 'fim_execucao']
#      14 #Converte para datetime as datas início e fim
# ---> 15 d1 = datetime.strptime(inicio, "%Y-%m-%d")
#      16 d2 = datetime.strptime(fim, "%Y-%m-%d")
#      18 #Calcula o tempo em dias entre a data de início e fim
#
# TypeError: strptime() argument 1 must be str, not Timestamp
